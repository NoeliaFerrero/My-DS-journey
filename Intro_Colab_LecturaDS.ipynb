# %% [markdown]
# <a href="https://colab.research.google.com/github/NoeliaFerrero/My-DS-journey/blob/main/Intro_Colab_LecturaDS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🐼 ¿Cómo cargar y descargar archivos CSV desde Google Colab? | ⏰ En menos de 60 segundos

# %%
#@title Vídeos por mirar 

# %%html
<hr>
<br>
<iframe width="560" height="315" src="https://www.youtube.com/embed/ft9bSa49k-A" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
<br>

<img width="500px" src="https://pbs.twimg.com/profile_banners/1256442419303809024/1591225079/1500x500"></img>
<b style="font-size:25px"> Hola dataclouder</b>
<a href="https://www.youtube.com/dataclouder" target="_blank" >Más vídeos aquí</a>
# Out:
# <hr>
# <br>
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ft9bSa49k-A" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# <br>
#
# <img width="500px" src="https://pbs.twimg.com/profile_banners/1256442419303809024/1591225079/1500x500"></img>
# <b style="font-size:25px"> Hola dataclouder</b>
# <a href="https://www.youtube.com/dataclouder" target="_blank" >Más vídeos aquí</a>

# %% [markdown]
# # Iniciando con Google Colab
#
# Objetivos
#
#
# *   aprender
# *   practicar
# *   programar

# %%
print("¡Hola Mundo Colab!")
# Out:
# ¡Hola Mundo Colab!

# %%
import pandas as pd

# %% [markdown]
# ## Carga de Datos

# %% [markdown]
# ### Carga de archivos locales

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-33615a8d-9a93-468c-8822-ebca7630b91a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33615a8d-9a93-468c-8822-ebca7630b91a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# #### Leeremos el archivo

# %%
data=pd.read_csv('BankChurners.csv')
data.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %% [markdown]
# ### Enlazar con Google Drive

# %% [markdown]
# Este es el código para que puedas autorizar la conexión entre Google Colab y Google Drive.
#
# Luego de ejecutarlo, te aparecerá un enlace al cual debes dar click y te dará un un código que debes copiar y pegar en una caja que te aparecerá, con esto das la autorización a partir de tu cuenta.
#
# Luego solo queda que hagas actualizar en la carpeta de archivos que se encuentra en el panel izquierdo y veras tu unidad montada y lista para utilizarse.

# %%
import os
from pathlib import Path

# %%
# este comando muestra mi directorio actual
dir_prin = Path.cwd()
print (dir_prin)
# Out:
# /content

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Para copiar el path donde se subio el archivo, hacer click derecho sobre el .csv y seleccionar la opcion copy path

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df=pd.read_csv('/content/BankChurners.csv')

# %%
# Observar las primeras filas
df.head()
# Out:
#    IdCliente  CodGeografia     Nombre Nombres2 Apellido  Nacimiento  \
# 0      27534           302    Candace      NaN  Chapman  1964-07-21
# 1      26893           276     Sharon        A     Deng  1975-12-24
# 2      26898           187     Ashley        R  Simmons  1961-06-16
# 3      12047           383  Alexandra      NaN    Davis  1974-03-25
# 4      26419           163   Geoffrey      NaN     Suri  1947-04-24
#
#   EstadoCivil Género  Ingresos  Hijos  Educación          Ocupación
# 0           S      F     60000      4  Bachiller  Obrero Calificado
# 1           M      F     40000      1  Bachiller  Obrero Calificado
# 2           S      F     10000      1  Bachiller            Militar
# 3           S      F     40000      0        EFP  Obrero Calificado
# 4           M      M    100000      3     Máster          Directivo

# %%
df=pd.read_excel('/Clientes.xlsx')

# %%
# Observar las primeras filas
df.head()
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# 2        Graduate        Married    $80K - $120K          Blue
# 3     High School        Unknown  Less than $40K          Blue
# 4      Uneducated        Married     $60K - $80K          Blue
#
#    Months_on_book  ...  Months_Inactive_12_mon  Contacts_Count_12_mon  \
# 0              39  ...                       1                      3
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

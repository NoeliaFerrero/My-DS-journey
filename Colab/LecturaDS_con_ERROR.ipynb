# %% [markdown]
# Este notebook ha sido creado para proporcionar ayuda en dataset que devuelven error al momento de ejecutar la sentencia read

# %%
import pandas as pd

# %% [markdown]
# <iframe src="https://prezi.com/p/embed/7gc728liticy/" id="iframe_container" frameborder="0" webkitallowfullscreen="" mozallowfullscreen="" allowfullscreen="" allow="autoplay; fullscreen" height="315" width="560"></iframe>

# %% [markdown]
# ## Carga de Datos

# %%
pwd #con esta linea de codigo averiguamos en que direcorio estamos trabajando
# Out:
# '/content'

# %%
archivo_git = 'https://raw.githubusercontent.com/tamaraberrondo/DATASETS/main/ElectronicsProductsPricingData%20-%20copia.csv'

# %%
#este codigo se usa cuando el deiminador es diferente en c/linea, ó incluso en la misma
# se prueba incluyendo varios separadores, pero tampoco lo toma bien
df = pd.read_csv(archivo_git, sep=';,:\s+', engine='python')
df.head(5)
# Out:
#   id,prices.amountMax,prices.amountMin,prices.availability,prices.condition,prices.currency,prices.dateSeen,prices.isSale,prices.merchant,prices.shipping,prices.sourceURLs,asins,brand,categories,dateAdded,dateUpdated,ean,imageURLs,keys,manufacturer,manufacturerNumber,name,primaryCategories,sourceURLs,upc,weight,,,,,;;;;
# 0  "AVphzgbJLJeJML43fA0o,104.99,104.99,Yes,New,US...
# 1  "AVpgMuGwLJeJML43KY_c,69,64.99,In Stock,New,US...
# 2  "AVpgMuGwLJeJML43KY_c,69,69,In Stock,New,USD,2...
# 3  "AVpgMuGwLJeJML43KY_c,69.99,69.99,Yes,New,USD,...
# 4  "AVpgMuGwLJeJML43KY_c,66.99,66.99,Yes,New,USD,...

# %%
df = pd.read_csv(archivo_git, 
                 delimiter=",", 
                 engine="python",
                 error_bad_lines=False,  
                 encoding='utf-8')
# Out:
# <ipython-input-20-2f48a07c94b6>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(archivo_git,
# Skipping line 2: ',' expected after '"'
# Skipping line 3: ',' expected after '"'
# Skipping line 4: ',' expected after '"'
# Skipping line 5: ',' expected after '"'
# Skipping line 6: ',' expected after '"'
# Skipping line 7: ',' expected after '"'
# Skipping line 8: ',' expected after '"'
# Skipping line 9: ',' expected after '"'
# Skipping line 10: ',' expected after '"'
# Skipping line 11: ',' expected after '"'
# Skipping line 12: ',' expected after '"'
# Skipping line 13: ',' expected after '"'
# Skipping line 14: ',' expected after '"'
# Skipping line 15: ',' expected after '"'
# Skipping line 16: ',' expected after '"'
# Skipping line 17: ',' expected after '"'
# Skipping line 18: ',' expected after '"'
# Skipping line 19: ',' expected after '"'
# ...

# %%
# este codigo con el archivo .csv, LO RECONOCE COMO UNA SOLA COLUMNA!!! 
import csv
df = pd.read_csv(archivo_git, header = None, sep='\t', quoting=csv.QUOTE_NONE, encoding='utf-8')
df.head(5)
# Out:
#                                                    0
# 0  id,prices.amountMax,prices.amountMin,prices.av...
# 1  "AVphzgbJLJeJML43fA0o,104.99,104.99,Yes,New,US...
# 2  "AVpgMuGwLJeJML43KY_c,69,64.99,In Stock,New,US...
# 3  "AVpgMuGwLJeJML43KY_c,69,69,In Stock,New,USD,2...
# 4  "AVpgMuGwLJeJML43KY_c,69.99,69.99,Yes,New,USD,...

# %%
# este codigo con el archivo .csv, LO RECONOCE COMO UNA SOLA COLUMNA!!! 
df = pd.read_csv(archivo_git, header = None, sep=';', quoting=3, error_bad_lines=False)
df.head(5)
# Out:
# <ipython-input-13-8de369fece35>:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv(archivo_git, header = None, sep=';', quoting=3, error_bad_lines=False)
#                                                    0    1    2    3    4
# 0  id,prices.amountMax,prices.amountMin,prices.av...  NaN  NaN  NaN  NaN
# 1  "AVphzgbJLJeJML43fA0o,104.99,104.99,Yes,New,US...  NaN  NaN  NaN  NaN
# 2  "AVpgMuGwLJeJML43KY_c,69,64.99,In Stock,New,US...  NaN  NaN  NaN  NaN
# 3  "AVpgMuGwLJeJML43KY_c,69,69,In Stock,New,USD,2...  NaN  NaN  NaN  NaN
# 4  "AVpgMuGwLJeJML43KY_c,69.99,69.99,Yes,New,USD,...  NaN  NaN  NaN  NaN

# %%
# ACA EL ARCHIVO YA FUE DESCARGADO Y VISUALIZADO CON EXCEL
# !head /content/ElectronicProductsPricingData_OK.csv
# Out:
# id;prices.amountMax;prices.amountMin;prices.availability;prices.condition;prices.currency;prices.dateSeen;prices.isSale;prices.merchant;prices.shipping;prices.sourceURLs;asins;brand;categories;dateAdded;dateUpdated;ean;imageURLs;keys;manufacturer;manufacturerNumber;name;primaryCategories;sourceURLs;upc;weight
# ...

# %%
archivo_local = '/content/ElectronicProductsPricingData_OK.csv'

# %%
# ESTA LO LEE OK!!! 
df_local=pd.read_csv(archivo_local, sep=';')  
df_local.head(5)
# Out:
#                      id  prices.amountMax  prices.amountMin  \
# 0  AVphzgbJLJeJML43fA0o            104.99            104.99
# 1  AVpgMuGwLJeJML43KY_c             69.00             64.99
# 2  AVpgMuGwLJeJML43KY_c             69.00             69.00
# 3  AVpgMuGwLJeJML43KY_c             69.99             69.99
# 4  AVpgMuGwLJeJML43KY_c             66.99             66.99
#
#   prices.availability prices.condition prices.currency  \
# 0                 Yes              New             USD
# 1            In Stock              New             USD
# 2            In Stock              New             USD
# 3                 Yes              New             USD
# 4                 Yes              New             USD
#
#                                      prices.dateSeen  prices.isSale  \
# 0  2017-03-30T06:00:00Z,2017-03-10T22:00:00Z,2017...          False
# 1                               2017-12-14T06:00:00Z           True
# ...

# %% [markdown]
# id,prices.amountMax,prices.amountMin,prices.availability,prices.condition,prices.currency,prices.dateSeen,prices.isSale,prices.merchant,prices.shipping,prices.sourceURLs,asins,brand,categories,dateAdded,dateUpdated,ean,imageURLs,keys,manufacturer,manufacturerNumber,name,primaryCategories,sourceURLs,upc,weight,,,,,;;;

# %%
df_local.shape
# Out:
# (2772, 26)

# %%
df_local.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2772 entries, 0 to 2771
# Data columns (total 26 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   2772 non-null   object
#  1   prices.amountMax     2772 non-null   float64
#  2   prices.amountMin     2772 non-null   float64
#  3   prices.availability  2772 non-null   object
#  4   prices.condition     2772 non-null   object
#  5   prices.currency      2772 non-null   object
#  6   prices.dateSeen      2772 non-null   object
#  7   prices.isSale        2772 non-null   bool
#  8   prices.merchant      2772 non-null   object
#  9   prices.shipping      1510 non-null   object
#  10  prices.sourceURLs    2772 non-null   object
#  11  asins                2772 non-null   object
#  12  brand                2772 non-null   object
#  13  categories           2772 non-null   object
#  14  dateAdded            2772 non-null   object
# ...

# %% [markdown]
# # Gracias!
# ## Espero que te lleves algo útil de este notebook 😀
